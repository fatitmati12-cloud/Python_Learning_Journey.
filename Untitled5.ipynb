# %%
length = input ("enter the length ")
wigth = input ("enter the wigth ")
length_a=float(length)
wigth_a=float (wigth)
area=length_a *wigth_a
stre_area= str (area)
print ("the area is " + stre_area)
mony=input ("how match mony of the meter ")
stre_mony = float ( mony )
the_totale=stre_mony*area
the_mony=str(the_totale)
print ("the totalae of mony is" + the_mony )
# Out:
# enter the length  5.3
# enter the wigth  7.8
# the area is 41.339999999999996
# how match mony of the meter  3.5
# the totalae of mony is144.69

# %%
print (341//60)
# Out:
# 5

# %%
print (341/60)
# Out:
# 5.683333333333334
