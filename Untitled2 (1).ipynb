# %%
name = input("what is your name ")
print ("hello habibi " +  name )
# Out:
# what is your name  fati
# hello habibi fati

# %%
print ("octu code " [3])
# Out:
# u

# %%
print (len("fatima mustafa"))
# Out:
# 14

# %%
number = input ("enter your pin number ")
print (len(str(number)))
# Out:
# enter your pin number  2315678
# 7

# %%
numbers = input("please enter two number ")
first_number = int(numbers[0])
second_number = int (numbers [1])
print (first_number +second_number)
# Out:
# please enter two number  56
# 11

# %%
numbers1 = input ('enter the tol ')
numbers2 = input ('enter the erth ')
first_number = int ( numbers1)
second_number = int (numbers2)
print (first_number * second_number )
# Out:
# enter the tol  7
# enter the erth  7
# 49

# %%
str_length = input ("please enter the length")
str_width = input ("please enter the width ")
length = float (str_length)
width  = float (str_width)
area = length * width 
str_area = str (area)
print (" the totale the area " +str_area)
# Out:
# please enter the length 5.5
# please enter the width  4.3
#  the totale the area 23.65

# %%
str_length = input (' enter the length ')
str_width = input ('enter the width ')
length = float (str_length)
width = float (str_width)
area = length * width
str_area = str (area)
print ("the totale " + str_area )
totale = input ("how much 1 meter")
str_totale = float (totale)
the_mony = str_totale *str_area 
str_themony = str (the_mony)
print (" the mony " +str_themony )

# %%
str_length = input (" enter the length please ")
str_width = input (" enter the width please ")
str_mony = input ("how mutch mony to 1 meter ") 
length = float (str_length)
width = float (str_width)
mony = float (str_mony) 
area = length * width 
totale_mony = area * mony 
area_str = str(area)
str_totaly = str (totale_mony)
print ("the area " +area_str  )
print (" the totale mony " + str_totaly )
# Out:
#  enter the length please  5
#  enter the width please  7.5
# how mutch mony to 1 meter  22
# the area 37.5
#  the totale mony 825.0
