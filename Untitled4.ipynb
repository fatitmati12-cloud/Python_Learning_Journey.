# %%
length=input ("enter the length ")
wigth= input ("enter the wigth ")
length_one= float (length)
wigth_one = float (wigth)
the_totale = length_one * wigth_one
str_totale = str(the_totale)
print("the totale area" +str_totale)
# Out:
# enter the length  5
# enter the wigth  4
# the totale area20.0
