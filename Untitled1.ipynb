# %%
print("fatima")
# Out:
# fatima

# %%
print("ilove you pythin")
print("")
print("print i love you python")
# Out:
# ilove you pythin
#
# print i love you python

# %%
print ("ilove python\nis very easy")
# Out:
# ilove python
# is very easy

# %%
print ("ilove python\nis very easy\nthis is anew line")
# Out:
# ilove python
# is very easy
# this is anew line
