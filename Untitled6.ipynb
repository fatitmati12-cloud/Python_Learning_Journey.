# %%
time=input ("enter the time you want calucs")
time_inte=float(time)
the_hour=time_inte//60
the_second=time_inte%60
stre_hour=str(the_hour)
stre_second=str(the_second)
print ("the houer is " + stre_hour +"the second is " + stre_second)
# Out:
# enter the time you want calucs 150
# the houer is 2.0the second is 30.0
